# %%
import pandas as pd
df=pd.read_excel('data.xlsx')
df['phone'] = df['number'].str.split(r',\s*')
df = df.explode('phone')
df = df.reset_index(drop=True)
df.to_excel('df.xlsx', index=False)
df
# Out:
#                                                    link  \
# 0     https://qarabazar.az/Apple-iPhone-larin-topdan...
# 1     https://qarabazar.az/Apple-iPhone-larin-topdan...
# 2     https://qarabazar.az/Wholesale-Suppliers-of-iP...
# 3     https://qarabazar.az/Wholesale-Suppliers-of-iP...
# 4             https://qarabazar.az/Sirga-adv147641.html
# ...                                                 ...
# 3322  https://qarabazar.az/Yalniz-birbasa-kreditorla...
# 3323  https://qarabazar.az/Dirnaq-ustasi-teleb-olunu...
# 3324  https://qarabazar.az/Ingilis-Dili-danisiq-klub...
# 3325  https://qarabazar.az/Kombi-temiri-kombi-ustasi...
# 3326  https://qarabazar.az/Magazanin-ofisinde-operat...
#
#                        name category                    number         phone
# 0       Mrs kathleen corwin      NaN   19016461295,85263154626   19016461295
# 1       Mrs kathleen corwin      NaN   19016461295,85263154626   85263154626
# ...
